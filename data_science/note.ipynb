# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# iris データセットをの読み込み
df = pd.read_csv("./iris.csv")
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
# Nameごとのヒストグラムの表示
df.hist(by="Name", column="SepalLength", sharex=True, sharey=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12b9df0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ba1bef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12ba41eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ba68e48>]],
#       dtype=object)

# %%
sns.pairplot(df, hue='Name')
